# %% [markdown]
# # Damped Harmonic Oscillator

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device=}")
# Out:
# Using device=device(type='cpu')

# %% [markdown]
# \begin{align}
# \ddot{x}(t) + 2\beta\omega_0\dot{x}(t) + \omega_0^2x(t) = 0
# \end{align}
#
# Ansatz, $x = \exp(\gamma t)$; $\gamma = -\omega_0\left[\beta \pm i\sqrt{1 - \beta^2}\right]$

# %%
def damped_sho(t, omega_0, beta, shift=0):
    # beta less than 1 for underdamped
    envel = beta * omega_0
    osc = torch.sqrt(1 - beta**2) * omega_0
    tau = t - shift
    data = torch.exp(-envel * tau) * torch.cos(osc * tau)
    data[tau < 0] = 0  # assume oscillator starts at tau = 0
    return data

def damped_sho_bilby(t, omega_0, beta, shift=0):
    # beta less than 1 for underdamped
    envel = beta * omega_0
    osc = np.sqrt(1 - beta**2) * omega_0
    tau = t - shift
    data = np.exp(-envel * tau) * np.cos(osc * tau)
    data[tau < 0] = 0
    return data

# %% [markdown]
# ## Plot

# %%
omega_0 = torch.tensor(1.3)
beta = torch.tensor(0.2)

t_vals = torch.linspace(-1, 10, 200)
for shift in [-1, 0, 1, 2]:
    x_vals = damped_sho(t_vals, omega_0=omega_0, beta=beta, shift=shift)
    plt.plot(t_vals, x_vals, label=f"{shift=}")
plt.xlabel("Time")
plt.ylabel("Displacement")
plt.axvline(x=0, linestyle='dotted', color='black')
plt.legend()
plt.title(f"Time Shifted Signal for omega_0 = {omega_0:.1f}, beta = {beta:.1f}")
# Out:
# Text(0.5, 1.0, 'Time Shifted Signal for omega_0 = 1.3, beta = 0.2')

# %%
injection_parameters = dict(omega_0=omega_0, beta=beta, shift=2)
print(injection_parameters)
# Out:
# {'omega_0': tensor(1.3000), 'beta': tensor(0.2000), 'shift': 2}

# %%
num_points = 200
t_vals = np.linspace(-1, 10, num_points)

# %%
sigma = 0.4

# %%
data = damped_sho(t_vals, **injection_parameters) + np.random.normal(0, sigma, t_vals.size)

# %%
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(t_vals, data, 'ko', label=r'Data')
ax.plot(t_vals, damped_sho(t_vals, **injection_parameters), '--r', label=r'Signal')
for shift in [0, 1, 3, 4]:
    x_vals = damped_sho(t_vals, omega_0=omega_0, beta=beta, shift=shift)
    plt.plot(t_vals, x_vals, alpha = 0.2)
ax.legend(fontsize=16)
ax.set_xlabel('Time', fontsize=16)
ax.set_ylabel('Displacement', fontsize=16)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
plt.savefig('./sho-data.pdf')
# plt.title(f"Data and Signal for Damped SHO (omega_0 = {omega_0:.1f}, beta = {beta:.1f})")

# %%
import bilby
from bilby.core.prior import Uniform, DeltaFunction
# Out:
# /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Prior for parameters

# %%
priors = dict()

priors['omega_0'] = Uniform(0.1, 2, name='omega_0', latex_label='$\omega_0$') #np array
priors['beta'] = Uniform(0, 0.5, name='beta', latex_label='$\\beta$') #np array
priors['shift'] = Uniform(-4, 4, name='shift', latex_label='$\Delta\;t$')

# %% [markdown]
# # Train embedding space first
#
# The aim is to make the network be agnostic to shift in time. Train embedding space to cluster shifts in intercept value.

# %%
from IPython.display import clear_output
from time import sleep

# %%
import torch

def get_data(omega_0=None, beta=None, shift=None, num_points=1):
    """Sample omega, beta, shift and return a batch of data with noise"""
    omega_0 = priors['omega_0'].sample() if omega_0 is None else omega_0
    omega_0 = torch.tensor(omega_0).to(dtype=torch.float32)
    beta = priors['beta'].sample() if beta is None else beta
    beta = torch.tensor(beta).to(dtype=torch.float32)
    shift = priors['shift'].sample() if shift is None else shift
    shift = torch.tensor(shift).to(dtype=torch.float32)

    t_vals = torch.linspace(-1, 10, num_points).to(dtype=torch.float32) #

    y = damped_sho(t_vals, omega_0=omega_0, beta=beta, shift=shift)
    y += sigma * torch.randn(size=y.size()).to(dtype=torch.float32)

    return t_vals, y, omega_0, beta, shift

# %% [markdown]
# # Add augmentation

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch import nn, optim
from torch.utils.tensorboard import SummaryWriter

# %%
num_simulations = 100000
num_repeats = 10

# %%
# %%time

theta_unshifted_vals = []
theta_shifted_vals = []
data_unshifted_vals = []
data_shifted_vals = []

for ii in range(num_simulations):
    # generated data with a fixed shift
    t_vals, y_unshifted, omega, beta, shift = get_data(num_points=num_points, shift=1)
    # create repeats
    theta_unshifted = torch.tensor([omega, beta, shift]).repeat(num_repeats, 1).to(device=device)
    theta_unshifted_vals.append(theta_unshifted)
    data_unshifted_vals.append(y_unshifted.repeat(num_repeats, 1).to(device=device))
    # generate shifted data
    theta_shifted = []
    data_shifted = []
    for _ in range(num_repeats):
        t_val, y_shifted, _omega, _beta, shift = get_data(
            omega_0=omega, beta=beta,  # omega and beta same as above
            shift=None,
            num_points=num_points
        )
        theta_shifted.append(torch.tensor([omega, beta, shift]))
        data_shifted.append(y_shifted)
    theta_shifted_vals.append(torch.stack(theta_shifted).to(device=device))
    data_shifted_vals.append(torch.stack(data_shifted).to(device=device))
# Out:
# /tmp/ipykernel_1982724/3156004060.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   omega_0 = torch.tensor(omega_0).to(dtype=torch.float32)
# /tmp/ipykernel_1982724/3156004060.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   beta = torch.tensor(beta).to(dtype=torch.float32)
# CPU times: user 4min 15s, sys: 2.31 s, total: 4min 17s
# Wall time: 4min 19s

# %%
class DataGenerator(Dataset):
    def __len__(self):
        return num_simulations

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        # return shifted and unshifted theta and data
        return (
            theta_shifted_vals[idx].to(dtype=torch.float32),
            theta_unshifted_vals[idx].to(dtype=torch.float32),
            data_shifted_vals[idx].to(dtype=torch.float32),
            data_unshifted_vals[idx].to(dtype=torch.float32)
        )

# %%
dataset = DataGenerator()

# %%
_, t, d, _ = dataset[4]

fig, ax = plt.subplots()

for (omega, beta, shift), points in zip(t, d):
    ax.plot(t_vals.clone().detach().cpu().numpy(), points.clone().detach().cpu().numpy(), 'o', markersize=0.8, label='$\\{x_i, y_i\\}$')
ax.set_xlabel('Time')
ax.set_ylabel('Displacement')
ax.set_title(f"Time Shifted Data for omega_0 = {t[0][0]:.1f}, beta = {t[0][1]:.1f}")
# plt.legend()
# Out:
# Text(0.5, 1.0, 'Time Shifted Data for omega_0 = 1.8, beta = 0.2')

# %%
train_set_size = int(0.8 * num_simulations)
val_set_size = int(0.1 * num_simulations)
test_set_size = int(0.1 * num_simulations)

train_data, val_data, test_data = torch.utils.data.random_split(
    dataset, [train_set_size, val_set_size, test_set_size])

# %%
TRAIN_BATCH_SIZE = 1000
VAL_BATCH_SIZE = 1000

train_data_loader = DataLoader(
    train_data, batch_size=TRAIN_BATCH_SIZE,
    shuffle=True
)

val_data_loader = DataLoader(
    val_data, batch_size=VAL_BATCH_SIZE,
    shuffle=True
)

test_data_loader = DataLoader(
    test_data, batch_size=1,
    shuffle=False
)

# %%
for theta, _, data_aug, data_orig in train_data_loader:
    break

# %%
len(train_data_loader), len(val_data_loader), len(test_data_loader)
# Out:
# (80, 10, 10000)

# %%
theta.shape, data_aug.shape, data_orig.shape
# Out:
# (torch.Size([1000, 10, 3]),
#  torch.Size([1000, 10, 200]),
#  torch.Size([1000, 10, 200]))

# %% [markdown]
# ## Define similarity loss

# %%
# implemented from https://github.com/violatingcp/codec
class VICRegLoss(nn.Module):
    def forward(self, x, y, wt_repr=1.0, wt_cov=1.0, wt_std=1.0):
        repr_loss = F.mse_loss(x, y)

        x = x - x.mean(dim=0)
        y = y - y.mean(dim=0)
        N = x.size(0)
        D = x.size(1)

        std_x = torch.sqrt(x.var(dim=0) + 0.0001)
        std_y = torch.sqrt(y.var(dim=0) + 0.0001)
        std_loss = torch.mean(F.relu(1 - std_x)) / 2 + torch.mean(F.relu(1 - std_y)) / 2

        x = (x-x.mean(dim=0))/x.std(dim=0)
        y = (y-y.mean(dim=0))/y.std(dim=0)

        # keep batch dim i.e. 0, unchanged
        cov_x = (x.transpose(1, 2) @ x) / (N - 1)
        cov_y = (y.transpose(1, 2) @ y) / (N - 1)
        cov_loss = self.off_diagonal(cov_x).pow_(2).sum().div(D)
        cov_loss += self.off_diagonal(cov_y).pow_(2).sum().div(D)

        s = wt_repr*repr_loss + wt_cov*cov_loss + wt_std*std_loss
        return s, repr_loss, cov_loss, std_loss

    def off_diagonal(self, x):
        num_batch, n, m = x.shape
        assert n == m
        # All off diagonal elements from complete batch flattened
        return x.flatten(start_dim=1)[...,:-1].view(num_batch, n - 1, n + 1)[...,1:].flatten()

# %%
vicreg_loss = VICRegLoss()

# %%
# modified 
class ConvResidualBlock(nn.Module):
    def __init__(
        self,
        channels,
        kernel_size=5,
        activation=F.relu,
        dropout_probability=0.1,
        use_batch_norm=True,
        zero_initialization=True,
    ):
        super().__init__()
        self.activation = activation

        self.use_batch_norm = use_batch_norm
        if use_batch_norm:
            self.batch_norm_layers = nn.ModuleList(
                [nn.BatchNorm1d(channels, eps=1e-3) for _ in range(2)]
            )
        self.conv_layers = nn.ModuleList(
            [nn.Conv1d(channels, channels, kernel_size=kernel_size, padding='same') for _ in range(2)] #2 is for 2 conv layers
        )
        self.dropout = nn.Dropout(p=dropout_probability)
        if zero_initialization:
            nn.init.uniform_(self.conv_layers[-1].weight, -1e-3, 1e-3)
            nn.init.uniform_(self.conv_layers[-1].bias, -1e-3, 1e-3)

    def forward(self, inputs):
        temps = inputs
        if self.use_batch_norm:
            temps = self.batch_norm_layers[0](temps)
        temps = self.activation(temps)
        temps = self.conv_layers[0](temps)
        if self.use_batch_norm:
            temps = self.batch_norm_layers[1](temps)
        temps = self.activation(temps)
        temps = self.dropout(temps)
        temps = self.conv_layers[1](temps)
        return inputs + temps


class ConvResidualNet(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels,
        hidden_channels,
        num_blocks=2,
        kernel_size=5,
        activation=F.relu,
        dropout_probability=0.1,
        use_batch_norm=True,
    ):
        super().__init__()
        self.hidden_channels = hidden_channels
        self.initial_layer = nn.Conv1d(
            in_channels=in_channels,
            out_channels=hidden_channels,
            kernel_size=kernel_size,
            padding='same',
        )
        self.blocks = nn.ModuleList(
            [
                ConvResidualBlock(
                    channels=hidden_channels,
                    activation=activation,
                    dropout_probability=dropout_probability,
                    use_batch_norm=use_batch_norm,
                    kernel_size=kernel_size,
                )
                for _ in range(num_blocks)
            ]
        )
        self.final_layer = nn.Conv1d(
            hidden_channels, out_channels, kernel_size=1, padding='same'
        )

    def forward(self, inputs):
        temps = self.initial_layer(inputs)
        for block in self.blocks:
            temps = block(temps)
        outputs = self.final_layer(temps)
        return outputs

# %%
num_dim = 3

class SimilarityEmbedding(nn.Module):
    """Simple Dense embedding"""
    def __init__(self, num_hidden_layers_h=1, activation=torch.relu):
        super().__init__()
        self.num_hidden_layers_h = num_hidden_layers_h

        self.layers_f = ConvResidualNet(in_channels=num_repeats, out_channels=1,
                                        hidden_channels=20, num_blocks=4,
                                        kernel_size=21)
        self.contraction_layer = nn.Sequential(
            nn.Linear(num_points, 100),
            nn.ReLU(),
            nn.Linear(100, num_dim)
        )
        self.expander_layer = nn.Linear(num_dim, 20)
        self.layers_h = nn.ModuleList([nn.Linear(20, 20) for _ in range(num_hidden_layers_h)])
        self.final_layer = nn.Linear(20, 6)

        self.activation = activation

    def forward(self, x):
        x = self.layers_f(x)
        x = self.contraction_layer(x)
        representation = torch.clone(x) #copy
        x = self.activation(self.expander_layer(x))
        for layer in self.layers_h:
            x = layer(x)
            x = self.activation(x) #activation of layer(x) in layers_h
        x = self.final_layer(x)
        return x, representation

# %%
similarity_embedding = SimilarityEmbedding(num_hidden_layers_h=2).to(device)

# %%
optimizer = optim.Adam(similarity_embedding.parameters(), lr=5e-3)
scheduler_1 = optim.lr_scheduler.ConstantLR(optimizer, total_iters=2)
scheduler_2 = optim.lr_scheduler.OneCycleLR(optimizer, total_steps=200, max_lr=5e-4)
scheduler_3 = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)
scheduler = optim.lr_scheduler.SequentialLR(
    optimizer, schedulers=[scheduler_1, scheduler_2, scheduler_3], milestones=[50, 150])

# %%
embed, rep = similarity_embedding(data_aug)
embed.shape, rep.shape
# Out:
# (torch.Size([1000, 1, 6]), torch.Size([1000, 1, 3]))

# %%
emb_aug, rep_aug = similarity_embedding(data_aug)
emb_orig, rep_orig = similarity_embedding(data_orig)
vicreg_loss(emb_aug, emb_orig)
# Out:
# (tensor(1.0881, grad_fn=<AddBackward0>),
#  tensor(6.8287e-07, grad_fn=<MseLossBackward0>),
#  tensor(0.0981, grad_fn=<AddBackward0>),
#  tensor(0.9900, grad_fn=<AddBackward0>))

# %%
# from tqdm.auto import tqdm

def train_one_epoch(epoch_index, tb_writer, **vicreg_kwargs):
    running_sim_loss = 0.
    last_sim_loss = 0.

    #for idx, val in enumerate(tqdm(train_data_loader, desc='train', leave=False), 1):
    for idx, val in enumerate(train_data_loader):
        augmented_theta, _, augmented_data, unshifted_data = val
        embedded_values_aug, _ = similarity_embedding(augmented_data)
        embedded_values_orig, _ = similarity_embedding(unshifted_data)
        sim_loss = 0

        similar_embedding_loss, _repr, _cov, _std = vicreg_loss(
            embedded_values_aug,
            embedded_values_orig,
            **vicreg_kwargs
        )
        sim_loss += similar_embedding_loss
        optimizer.zero_grad()
        sim_loss.backward()
        optimizer.step()
        # Gather data and report
        running_sim_loss += sim_loss.item()
        if idx % 10 == 0:
            last_sim_loss = running_sim_loss / 10
            tb_x = epoch_index * len(train_data_loader) + idx
            tb_writer.add_scalar('SimLoss/train', last_sim_loss, tb_x)
            running_sim_loss = 0.
    return last_sim_loss


def val_one_epoch(epoch_index, tb_writer, **vicreg_kwargs):
    running_sim_loss = 0.
    last_sim_loss = 0.

    #for idx, val in enumerate(tqdm(val_data_loader, desc='val', leave=False), 1):
    for idx, val in enumerate(val_data_loader):
        augmented_theta, _, augmented_data, unshifted_data = val
        embedded_values_aug, _ = similarity_embedding(augmented_data)
        embedded_values_orig, _ = similarity_embedding(unshifted_data)
        sim_loss = 0

        similar_embedding_loss, _repr, _cov, _std = vicreg_loss(
            embedded_values_aug,
            embedded_values_orig,
            **vicreg_kwargs
        )
        sim_loss += similar_embedding_loss

        running_sim_loss += sim_loss.item()
        if idx % 5 == 0:
            last_sim_loss = running_sim_loss / 5
            tb_x = epoch_index * len(val_data_loader) + idx + 1
            tb_writer.add_scalar('SimLoss/val', last_sim_loss, tb_x)
            tb_writer.flush()
            print(f'Last {_repr.item():.2f}; {_cov.item():.2f}; {_std.item():.2f}')
            running_sim_loss = 0.
    tb_writer.flush()
    return last_sim_loss

# %%
writer = SummaryWriter("damped-harmonic-oscillator-similarity-embedding-training", flush_secs=5)
epoch_number = 0

# %%
sum_param=0
for name, param in similarity_embedding.named_parameters():
    if param.requires_grad:
        sum_param+=param.numel()
print(sum_param)
# Out:
# 93370

# %%
# PATH = './damped-harmonic-oscillator-similarity-embedding-weights.neurips.pth'
# similarity_embedding.load_state_dict(torch.load(PATH, map_location=device))
# similarity_embedding.eval()

# %%
# %%time
# UNCOMMENT AND RUN TO TRAIN FROM SCRATCH
EPOCHS = 500

#for epoch in tqdm(range(1, EPOCHS + 1)):
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))
    wt_repr, wt_cov, wt_std = (1, 1, 1)

    if epoch < 20:
        wt_repr, wt_cov, wt_std = (5, 1, 5)
    elif epoch < 45:
        wt_repr, wt_cov, wt_std = (2, 2, 1)

    print(f"VicReg wts: {wt_repr=} {wt_cov=} {wt_std=}")
    # Gradient tracking
    similarity_embedding.train(True)
    avg_train_loss = train_one_epoch(epoch_number, writer,
                                     wt_repr=wt_repr, wt_cov=wt_cov, wt_std=wt_std)
    
    # no gradient tracking, for validation
    similarity_embedding.train(False)
    avg_val_loss = val_one_epoch(epoch_number, writer,
                                 wt_repr=wt_repr, wt_cov=wt_cov, wt_std=wt_std)
    
    print(f"Train/Val Sim Loss after epoch: {avg_train_loss:.4f}/{avg_val_loss:.4f}")

    epoch_number += 1
    try:
        scheduler.step(avg_val_loss)
    except TypeError:
        scheduler.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:6
#
# NameError: name 'epoch_number' is not defined

# %%
PATH = './damped-harmonic-oscillator-similarity-embedding-weights.neurips.pth'
torch.save(similarity_embedding.state_dict(), PATH)

# %% [markdown]
# ## See embedded space

# %% [markdown]
# # Varying Omega

# %%
# C1 orange
# C2 green
# C3 red
# C4 purple

similarity_outputs_1 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][0][0] < 0.4) and (theta_test.T[0][0][0] > 0.2)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_1.append(similarity_output)
    
similarity_outputs_2 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][0][0] < 1.6) and (theta_test.T[0][0][0] > 1.4)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_2.append(similarity_output)

similarity_outputs_3 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][0][0] < 0.8) and (theta_test.T[0][0][0] > 0.6)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_3.append(similarity_output)

similarity_outputs_4 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][0][0] < 0.6) and (theta_test.T[0][0][0] > 0.4)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_4.append(similarity_output)
# Out:
# /tmp/ipykernel_1982724/1045489057.py:9: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3697.)
#   if not ((theta_test.T[0][0][0] < 0.4) and (theta_test.T[0][0][0] > 0.2)):

# %%
similarity_outputs_1 = torch.stack(similarity_outputs_1)
similarity_outputs_2 = torch.stack(similarity_outputs_2)
similarity_outputs_3 = torch.stack(similarity_outputs_3)
similarity_outputs_4 = torch.stack(similarity_outputs_4)
similarity_outputs_2.shape
# Out:
# torch.Size([1036, 1, 1, 3])

# %%
import corner

figure = corner.corner(
    similarity_outputs_1.cpu().numpy().reshape((similarity_outputs_1.shape[0]*similarity_outputs_1.shape[2], num_dim)),
    quantiles=[0.16, 0.5], color="C1"#, range = [[-1.2,-0.8], [-1.2,-0.8], [-1.2,-0.8]]
)

figure = corner.corner(
    similarity_outputs_2.cpu().numpy().reshape((similarity_outputs_2.shape[0]*similarity_outputs_2.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C2"#, range = [[-1.2,-0.8], [-1.2,-0.8], [-1.2,-0.8]]
)

figure = corner.corner(
    similarity_outputs_3.cpu().numpy().reshape((similarity_outputs_3.shape[0]*similarity_outputs_3.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C3"
)

figure = corner.corner(
    similarity_outputs_4.cpu().numpy().reshape((similarity_outputs_4.shape[0]*similarity_outputs_4.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C4"
)

# %% [markdown]
# # Varying Beta

# %%
similarity_embedding.train(False)

similarity_outputs_1 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][1][0] < 0.2) and (theta_test.T[0][1][0] > 0.1)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_1.append(similarity_output)

similarity_outputs_2 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][1][0] < 0.3) and (theta_test.T[0][1][0] > 0.2)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_2.append(similarity_output)
    
similarity_outputs_3 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][1][0] < 0.4) and (theta_test.T[0][1][0] > 0.3)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_3.append(similarity_output)
    
similarity_outputs_4 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test.T[0][1][0] < 0.5) and (theta_test.T[0][1][0] > 0.4)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_4.append(similarity_output)

# %%
similarity_outputs_1 = torch.stack(similarity_outputs_1)
similarity_outputs_2 = torch.stack(similarity_outputs_2)
similarity_outputs_3 = torch.stack(similarity_outputs_3)
similarity_outputs_4 = torch.stack(similarity_outputs_4)

# %%
import corner

figure = corner.corner(
    similarity_outputs_1.cpu().numpy().reshape((similarity_outputs_1.shape[0]*similarity_outputs_1.shape[2], num_dim)),
    quantiles=[0.16, 0.5], color="C1"
)

figure = corner.corner(
    similarity_outputs_2.cpu().numpy().reshape((similarity_outputs_2.shape[0]*similarity_outputs_2.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C2"
)

figure = corner.corner(
    similarity_outputs_3.cpu().numpy().reshape((similarity_outputs_3.shape[0]*similarity_outputs_3.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C3"
)

figure = corner.corner(
    similarity_outputs_4.cpu().numpy().reshape((similarity_outputs_4.shape[0]*similarity_outputs_4.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C4"
)

# %% [markdown]
# # Varying Omega with constant Beta

# %%
#orange green red purple

similarity_outputs_1 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test[0][0][0] < 0.75) and (theta_test[0][0][0] > 0.5) and \
            (theta_test[0][0][1] < 0.3) and (theta_test[0][0][1] > 0.2)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_1.append(similarity_output)
# print(similarity_outputs_1)

similarity_outputs_2 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test[0][0][0] < 1.5) and (theta_test[0][0][0] > 1.25) and \
            (theta_test[0][0][1] < 0.2) and (theta_test[0][0][1] > 0.1)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
#         print(similarity_output.shape)
    similarity_outputs_2.append(similarity_output)
#print(similarity_outputs_2)
    
similarity_outputs_3 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test[0][0][0] < 1.75) and (theta_test[0][0][0] > 1.5) and \
            (theta_test[0][0][1] < 0.4) and (theta_test[0][0][1] > 0.3)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_3.append(similarity_output)

similarity_outputs_4 = []

for idx, (_, theta_test, data_test, data_test_orig) in enumerate(test_data_loader):
    if not ((theta_test[0][0][0] < 0.5) and (theta_test[0][0][0] > 0.25) and \
            (theta_test[0][0][1] < 0.5) and (theta_test[0][0][1] > 0.4)):
        continue
    with torch.no_grad():
        _, similarity_output = similarity_embedding(data_test)
    similarity_outputs_4.append(similarity_output)

# %%
similarity_outputs_1 = torch.stack(similarity_outputs_1)
similarity_outputs_2 = torch.stack(similarity_outputs_2)
similarity_outputs_3 = torch.stack(similarity_outputs_3)
similarity_outputs_4 = torch.stack(similarity_outputs_4)
len(similarity_outputs_1), len(similarity_outputs_2), len(similarity_outputs_3), len(similarity_outputs_4)
# Out:
# (243, 273, 235, 240)

# %%
figure = corner.corner(
    similarity_outputs_1.cpu().numpy().reshape((similarity_outputs_1.shape[0]*similarity_outputs_1.shape[2], num_dim)),
    quantiles=[0.16, 0.5], color="C1"
)

figure = corner.corner(
    similarity_outputs_2.cpu().numpy().reshape((similarity_outputs_2.shape[0]*similarity_outputs_2.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C2"
)

figure = corner.corner(
    similarity_outputs_3.cpu().numpy().reshape((similarity_outputs_3.shape[0]*similarity_outputs_3.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C3"
)

figure = corner.corner(
    similarity_outputs_4.cpu().numpy().reshape((similarity_outputs_4.shape[0]*similarity_outputs_4.shape[2], num_dim)),
    quantiles=[0.16, 0.5], fig=figure, color="C4"
)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# # Freeze weights, used as embedding network in MAF

# %%
from nflows.distributions import StandardNormal
from nflows.flows import Flow
from nflows.transforms.autoregressive import MaskedAffineAutoregressiveTransform
from nflows.transforms import CompositeTransform, RandomPermutation

import nflows.utils as torchutils

# %%
class EmbeddingNet(nn.Module):
    """Wrapper around the similarity embedding defined above"""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.representation_net = SimilarityEmbedding(num_hidden_layers_h=2)
        self.representation_net.load_state_dict(similarity_embedding.state_dict())

        # the expander network is unused and hence don't track gradients
        for name, param in self.representation_net.named_parameters():
            if 'expander_layer' in name or 'layers_h' in name or 'final_layer' in name:
                param.requires_grad = False

        # freeze part of the conv layer of embedding_net
        for name, param in self.representation_net.named_parameters():
            if 'layers_f.blocks.0' in name or 'layers_f.blocks.1' in name:
                param.requires_grad = False

        self.context_layer = nn.Identity()

    def forward(self, x):
        batch_size, _, dims = x.shape
        x = x.reshape(batch_size, 1, dims).repeat(1, num_repeats, 1)
        _, rep = self.representation_net(x)
        return self.context_layer(rep.reshape(batch_size, num_dim))

# %%
num_transforms = 5
num_blocks = 4
hidden_features = 30

context_features = num_dim

base_dist = StandardNormal([2])

transforms = []
for _ in range(num_transforms):
    block = [
        MaskedAffineAutoregressiveTransform(
            features=2,  # 2-dim posterior
            hidden_features=hidden_features,
            context_features=context_features,
            num_blocks=num_blocks,
            activation=torch.tanh,
            use_batch_norm=False,
            use_residual_blocks=True,
            dropout_probability=0.01,
        ),
        RandomPermutation(features=2)
    ]
    transforms += block

transform = CompositeTransform(transforms)

embedding_net = EmbeddingNet()

flow = Flow(transform, base_dist, embedding_net).to(device=device)

# %%
sum(p.numel() for p in flow._embedding_net.parameters() if p.requires_grad)
# Out:
# 58463

# %%
print("Total number of trainable parameters: ", sum(p.numel() for p in flow.parameters() if p.requires_grad))
# Out:
# Total number of trainable parameters:  99733

# %% [markdown]
# # Train/Validate

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.

    for idx, val in enumerate(train_data_loader, 1):
        augmented_theta, _, augmented_data, _ = val
        augmented_theta = augmented_theta[...,0:2]

        theta = augmented_theta.reshape(-1, 2)
        data = augmented_data.reshape(-1, 1, num_points)

        flow_loss = -flow.log_prob(theta, context=data).mean()

        optimizer.zero_grad()
        flow_loss.backward()
        optimizer.step()

        running_loss += flow_loss.item()
        if idx % 10 == 0:
            last_loss = running_loss / 10 # avg loss
            print(' Avg. train loss/batch after {} batches = {:.4f}'.format(idx, last_loss))
            tb_x = epoch_index * len(train_data_loader) + idx
            tb_writer.add_scalar('Flow Loss/train', last_loss, tb_x)
            tb_writer.flush()
            running_loss = 0.
    return last_loss


def val_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.

    for idx, val in enumerate(val_data_loader, 1):
        augmented_theta, _, augmented_data, _ = val
        augmented_theta = augmented_theta[...,0:2]

        theta = augmented_theta.reshape(-1, 2)
        data = augmented_data.reshape(-1, 1, num_points)

        flow_loss = -flow.log_prob(theta, context=data).mean()
        loss = flow_loss.item()

        running_loss += flow_loss.item()
        if idx % 5 == 0:
            last_loss = running_loss / 5
            tb_x = epoch_index * len(val_data_loader) + idx + 1
            tb_writer.add_scalar('Flow Loss/val', last_loss, tb_x)

            tb_writer.flush()
            running_loss = 0.
    tb_writer.flush()
    return last_loss

# %%
optimizer = optim.SGD(flow.parameters(), lr=1e-4, momentum=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, threshold=0.01)

# %%
writer = SummaryWriter("damped-harmonic-oscillator-flow-training-neurips")
epoch_number = 0

# %%
# PATH2 = './damped-harmonic-oscillator-with-similarity-embedding-flow-weights.neurips.pth'
# flow.load_state_dict(torch.load(PATH2, map_location=device))
# flow.eval()

# %% [markdown]
# #### Profile MACs

# %%
# from torchprofile import profile_macs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 from torchprofile import profile_macs
#
# ModuleNotFoundError: No module named 'torchprofile'

# %%
data = torch.randn(1000, 1, 200).to(device)
theta = torch.randn(1000, 2).to(device)
# num_macs_embed = profile_macs(flow._embedding_net, args=(data,))
embedded_data = flow._embedding_net(data)

# %%
# num_macs_forward = profile_macs(flow._transform, args=(theta, embedded_data))
# print("#MACs: {:.2e}".format(num_macs_forward+num_macs_embed))
# Out:
# #MACs: 9.15e+07
# /home/deep/miniconda3/envs/mlpe-base/lib/python3.9/site-packages/torchprofile/profile.py:22: UserWarning: No handlers found: "aten::new_zeros". Skipped.
#   warnings.warn('No handlers found: "{}". Skipped.'.format(
# /home/deep/miniconda3/envs/mlpe-base/lib/python3.9/site-packages/torchprofile/profile.py:22: UserWarning: No handlers found: "aten::softplus". Skipped.
#   warnings.warn('No handlers found: "{}". Skipped.'.format(
# /home/deep/miniconda3/envs/mlpe-base/lib/python3.9/site-packages/torchprofile/profile.py:22: UserWarning: No handlers found: "aten::log". Skipped.
#   warnings.warn('No handlers found: "{}". Skipped.'.format(
# /home/deep/miniconda3/envs/mlpe-base/lib/python3.9/site-packages/torchprofile/profile.py:22: UserWarning: No handlers found: "aten::index_select". Skipped.
#   warnings.warn('No handlers found: "{}". Skipped.'.format(

# %%
# %%time
# UNCOMMENT AND RUN TO TRAIN FROM SCRATCH
EPOCHS = 100

for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))
    # Gradient tracking
    flow.train(True)
    avg_train_loss = train_one_epoch(epoch_number, writer)

    # no gradient tracking, for validation
    flow.train(False)
    avg_val_loss = val_one_epoch(epoch_number, writer)

    print(f"Train/Val flow Loss after epoch: {avg_train_loss:.4f}/{avg_val_loss:.4f}")
    for param_group in optimizer.param_groups:
        print("Current LR = {:.3e}".format(param_group['lr']))
    epoch_number += 1
    try:
        scheduler.step(avg_val_loss)
    except TypeError:
        scheduler.step()
# Out:
# EPOCH 1:
#  Avg. train loss/batch after 10 batches = 5.3038
#  Avg. train loss/batch after 20 batches = 5.1930
#  Avg. train loss/batch after 30 batches = 5.0756
#  Avg. train loss/batch after 40 batches = 4.9611
#  Avg. train loss/batch after 50 batches = 4.8548
#  Avg. train loss/batch after 60 batches = 4.7465
#  Avg. train loss/batch after 70 batches = 4.6383
#  Avg. train loss/batch after 80 batches = 4.5350
# Train/Val flow Loss after epoch: 4.5350/4.4716
# Current LR = 1.000e-04
# EPOCH 2:
#  Avg. train loss/batch after 10 batches = 4.4296
#  Avg. train loss/batch after 20 batches = 4.3287
#  Avg. train loss/batch after 30 batches = 4.2296
#  Avg. train loss/batch after 40 batches = 4.1238
#  Avg. train loss/batch after 50 batches = 4.0291
#  Avg. train loss/batch after 60 batches = 3.9281
#  Avg. train loss/batch after 70 batches = 3.8399
#  Avg. train loss/batch after 80 batches = 3.7412
# Train/Val flow Loss after epoch: 3.7412/3.6869
# Current LR = 1.000e-04
# EPOCH 3:
#  Avg. train loss/batch after 10 batches = 3.6466
#  Avg. train loss/batch after 20 batches = 3.5529
#  Avg. train loss/batch after 30 batches = 3.4646
#  Avg. train loss/batch after 40 batches = 3.3756
#  Avg. train loss/batch after 50 batches = 3.2870
#  Avg. train loss/batch after 60 batches = 3.2028
#  Avg. train loss/batch after 70 batches = 3.1147
#  Avg. train loss/batch after 80 batches = 3.0251
# Train/Val flow Loss after epoch: 3.0251/2.9829
# Current LR = 1.000e-04
# EPOCH 4:
#  Avg. train loss/batch after 10 batches = 2.9453
#  Avg. train loss/batch after 20 batches = 2.8578
#  Avg. train loss/batch after 30 batches = 2.7835
#  Avg. train loss/batch after 40 batches = 2.6951
#  Avg. train loss/batch after 50 batches = 2.6210
#  Avg. train loss/batch after 60 batches = 2.5420
#  Avg. train loss/batch after 70 batches = 2.4637
#  Avg. train loss/batch after 80 batches = 2.3925
# Train/Val flow Loss after epoch: 2.3925/2.3516
# Current LR = 1.000e-04
# EPOCH 5:
#  Avg. train loss/batch after 10 batches = 2.3196
#  Avg. train loss/batch after 20 batches = 2.2460
#  Avg. train loss/batch after 30 batches = 2.1780
#  Avg. train loss/batch after 40 batches = 2.1107
#  Avg. train loss/batch after 50 batches = 2.0455
#  Avg. train loss/batch after 60 batches = 1.9762
#  Avg. train loss/batch after 70 batches = 1.9208
#  Avg. train loss/batch after 80 batches = 1.8641
# Train/Val flow Loss after epoch: 1.8641/1.8261
# Current LR = 1.000e-04
# EPOCH 6:
#  Avg. train loss/batch after 10 batches = 1.8049
#  Avg. train loss/batch after 20 batches = 1.7490
#  Avg. train loss/batch after 30 batches = 1.6978
#  Avg. train loss/batch after 40 batches = 1.6483
#  Avg. train loss/batch after 50 batches = 1.6008
#  Avg. train loss/batch after 60 batches = 1.5561
#  Avg. train loss/batch after 70 batches = 1.5170
#  Avg. train loss/batch after 80 batches = 1.4766
# Train/Val flow Loss after epoch: 1.4766/1.4516
# Current LR = 1.000e-04
# EPOCH 7:
#  Avg. train loss/batch after 10 batches = 1.4366
#  Avg. train loss/batch after 20 batches = 1.4096
#  Avg. train loss/batch after 30 batches = 1.3728
#  Avg. train loss/batch after 40 batches = 1.3435
#  Avg. train loss/batch after 50 batches = 1.3213
#  Avg. train loss/batch after 60 batches = 1.2859
#  Avg. train loss/batch after 70 batches = 1.2644
#  Avg. train loss/batch after 80 batches = 1.2477
# Train/Val flow Loss after epoch: 1.2477/1.2359
# Current LR = 1.000e-04
# EPOCH 8:
#  Avg. train loss/batch after 10 batches = 1.2226
#  Avg. train loss/batch after 20 batches = 1.2070
#  Avg. train loss/batch after 30 batches = 1.1828
#  Avg. train loss/batch after 40 batches = 1.1674
#  Avg. train loss/batch after 50 batches = 1.1545
#  Avg. train loss/batch after 60 batches = 1.1469
#  Avg. train loss/batch after 70 batches = 1.1326
#  Avg. train loss/batch after 80 batches = 1.1101
# Train/Val flow Loss after epoch: 1.1101/1.1139
# Current LR = 1.000e-04
# EPOCH 9:
#  Avg. train loss/batch after 10 batches = 1.1040
#  Avg. train loss/batch after 20 batches = 1.0925
#  Avg. train loss/batch after 30 batches = 1.0743
#  Avg. train loss/batch after 40 batches = 1.0647
#  Avg. train loss/batch after 50 batches = 1.0577
#  Avg. train loss/batch after 60 batches = 1.0444
#  Avg. train loss/batch after 70 batches = 1.0378
#  Avg. train loss/batch after 80 batches = 1.0273
# Train/Val flow Loss after epoch: 1.0273/1.0314
# Current LR = 1.000e-04
# EPOCH 10:
#  Avg. train loss/batch after 10 batches = 1.0278
#  Avg. train loss/batch after 20 batches = 1.0108
#  Avg. train loss/batch after 30 batches = 0.9980
#  Avg. train loss/batch after 40 batches = 0.9931
#  Avg. train loss/batch after 50 batches = 0.9751
#  Avg. train loss/batch after 60 batches = 0.9804
#  Avg. train loss/batch after 70 batches = 0.9625
#  Avg. train loss/batch after 80 batches = 0.9648
# Train/Val flow Loss after epoch: 0.9648/0.9662
# Current LR = 1.000e-04
# EPOCH 11:
#  Avg. train loss/batch after 10 batches = 0.9518
#  Avg. train loss/batch after 20 batches = 0.9539
#  Avg. train loss/batch after 30 batches = 0.9344
#  Avg. train loss/batch after 40 batches = 0.9332
#  Avg. train loss/batch after 50 batches = 0.9196
#  Avg. train loss/batch after 60 batches = 0.9201
#  Avg. train loss/batch after 70 batches = 0.9064
#  Avg. train loss/batch after 80 batches = 0.9088
# Train/Val flow Loss after epoch: 0.9088/0.9123
# Current LR = 1.000e-04
# EPOCH 12:
#  Avg. train loss/batch after 10 batches = 0.9017
#  Avg. train loss/batch after 20 batches = 0.8890
#  Avg. train loss/batch after 30 batches = 0.8873
#  Avg. train loss/batch after 40 batches = 0.8809
#  Avg. train loss/batch after 50 batches = 0.8632
#  Avg. train loss/batch after 60 batches = 0.8595
#  Avg. train loss/batch after 70 batches = 0.8553
#  Avg. train loss/batch after 80 batches = 0.8572
# Train/Val flow Loss after epoch: 0.8572/0.8575
# Current LR = 1.000e-04
# EPOCH 13:
#  Avg. train loss/batch after 10 batches = 0.8380
#  Avg. train loss/batch after 20 batches = 0.8313
#  Avg. train loss/batch after 30 batches = 0.8301
#  Avg. train loss/batch after 40 batches = 0.8279
#  Avg. train loss/batch after 50 batches = 0.8292
#  Avg. train loss/batch after 60 batches = 0.8154
#  Avg. train loss/batch after 70 batches = 0.8145
#  Avg. train loss/batch after 80 batches = 0.7910
# Train/Val flow Loss after epoch: 0.7910/0.7985
# Current LR = 1.000e-04
# EPOCH 14:
#  Avg. train loss/batch after 10 batches = 0.7999
#  Avg. train loss/batch after 20 batches = 0.7902
#  Avg. train loss/batch after 30 batches = 0.7685
#  Avg. train loss/batch after 40 batches = 0.7672
#  Avg. train loss/batch after 50 batches = 0.7640
#  Avg. train loss/batch after 60 batches = 0.7569
#  Avg. train loss/batch after 70 batches = 0.7576
#  Avg. train loss/batch after 80 batches = 0.7493
# Train/Val flow Loss after epoch: 0.7493/0.7378
# Current LR = 1.000e-04
# EPOCH 15:
#  Avg. train loss/batch after 10 batches = 0.7459
#  Avg. train loss/batch after 20 batches = 0.7381
#  Avg. train loss/batch after 30 batches = 0.7201
#  Avg. train loss/batch after 40 batches = 0.7222
#  Avg. train loss/batch after 50 batches = 0.7005
#  Avg. train loss/batch after 60 batches = 0.6953
#  Avg. train loss/batch after 70 batches = 0.7004
#  Avg. train loss/batch after 80 batches = 0.6811
# Train/Val flow Loss after epoch: 0.6811/0.6847
# Current LR = 1.000e-04
# EPOCH 16:
#  Avg. train loss/batch after 10 batches = 0.6791
#  Avg. train loss/batch after 20 batches = 0.6703
#  Avg. train loss/batch after 30 batches = 0.6625
#  Avg. train loss/batch after 40 batches = 0.6600
#  Avg. train loss/batch after 50 batches = 0.6451
#  Avg. train loss/batch after 60 batches = 0.6361
#  Avg. train loss/batch after 70 batches = 0.6300
#  Avg. train loss/batch after 80 batches = 0.6242
# Train/Val flow Loss after epoch: 0.6242/0.6250
# Current LR = 1.000e-04
# EPOCH 17:
#  Avg. train loss/batch after 10 batches = 0.6189
#  Avg. train loss/batch after 20 batches = 0.6071
#  Avg. train loss/batch after 30 batches = 0.5848
#  Avg. train loss/batch after 40 batches = 0.5871
#  Avg. train loss/batch after 50 batches = 0.5780
#  Avg. train loss/batch after 60 batches = 0.5656
#  Avg. train loss/batch after 70 batches = 0.5682
#  Avg. train loss/batch after 80 batches = 0.5415
# Train/Val flow Loss after epoch: 0.5415/0.5437
# Current LR = 1.000e-04
# EPOCH 18:
#  Avg. train loss/batch after 10 batches = 0.5349
#  Avg. train loss/batch after 20 batches = 0.5285
#  Avg. train loss/batch after 30 batches = 0.5169
#  Avg. train loss/batch after 40 batches = 0.5163
#  Avg. train loss/batch after 50 batches = 0.4984
#  Avg. train loss/batch after 60 batches = 0.4935
#  Avg. train loss/batch after 70 batches = 0.4717
#  Avg. train loss/batch after 80 batches = 0.4690
# Train/Val flow Loss after epoch: 0.4690/0.4681
# Current LR = 1.000e-04
# EPOCH 19:
#  Avg. train loss/batch after 10 batches = 0.4614
#  Avg. train loss/batch after 20 batches = 0.4455
#  Avg. train loss/batch after 30 batches = 0.4245
#  Avg. train loss/batch after 40 batches = 0.4281
#  Avg. train loss/batch after 50 batches = 0.4246
#  Avg. train loss/batch after 60 batches = 0.3905
#  Avg. train loss/batch after 70 batches = 0.3854
#  Avg. train loss/batch after 80 batches = 0.3858
# Train/Val flow Loss after epoch: 0.3858/0.3772
# Current LR = 1.000e-04
# EPOCH 20:
#  Avg. train loss/batch after 10 batches = 0.3681
#  Avg. train loss/batch after 20 batches = 0.3555
#  Avg. train loss/batch after 30 batches = 0.3398
#  Avg. train loss/batch after 40 batches = 0.3279
#  Avg. train loss/batch after 50 batches = 0.3229
#  Avg. train loss/batch after 60 batches = 0.3163
#  Avg. train loss/batch after 70 batches = 0.2959
#  Avg. train loss/batch after 80 batches = 0.2914
# Train/Val flow Loss after epoch: 0.2914/0.2930
# Current LR = 1.000e-04
# EPOCH 21:
#  Avg. train loss/batch after 10 batches = 0.2827
#  Avg. train loss/batch after 20 batches = 0.2646
#  Avg. train loss/batch after 30 batches = 0.2564
#  Avg. train loss/batch after 40 batches = 0.2368
#  Avg. train loss/batch after 50 batches = 0.2322
#  Avg. train loss/batch after 60 batches = 0.2185
#  Avg. train loss/batch after 70 batches = 0.2019
#  Avg. train loss/batch after 80 batches = 0.1870
# Train/Val flow Loss after epoch: 0.1870/0.1940
# Current LR = 1.000e-04
# EPOCH 22:
#  Avg. train loss/batch after 10 batches = 0.1829
#  Avg. train loss/batch after 20 batches = 0.1819
#  Avg. train loss/batch after 30 batches = 0.1562
#  Avg. train loss/batch after 40 batches = 0.1476
#  Avg. train loss/batch after 50 batches = 0.1350
#  Avg. train loss/batch after 60 batches = 0.1381
#  Avg. train loss/batch after 70 batches = 0.1206
#  Avg. train loss/batch after 80 batches = 0.1149
# Train/Val flow Loss after epoch: 0.1149/0.1115
# Current LR = 1.000e-04
# EPOCH 23:
#  Avg. train loss/batch after 10 batches = 0.0968
#  Avg. train loss/batch after 20 batches = 0.0822
#  Avg. train loss/batch after 30 batches = 0.0804
#  Avg. train loss/batch after 40 batches = 0.0748
#  Avg. train loss/batch after 50 batches = 0.0653
#  Avg. train loss/batch after 60 batches = 0.0552
#  Avg. train loss/batch after 70 batches = 0.0474
#  Avg. train loss/batch after 80 batches = 0.0364
# Train/Val flow Loss after epoch: 0.0364/0.0391
# Current LR = 1.000e-04
# EPOCH 24:
#  Avg. train loss/batch after 10 batches = 0.0283
#  Avg. train loss/batch after 20 batches = 0.0062
#  Avg. train loss/batch after 30 batches = 0.0054
#  Avg. train loss/batch after 40 batches = 0.0171
#  Avg. train loss/batch after 50 batches = -0.0066
#  Avg. train loss/batch after 60 batches = -0.0154
#  Avg. train loss/batch after 70 batches = -0.0305
#  Avg. train loss/batch after 80 batches = -0.0365
# Train/Val flow Loss after epoch: -0.0365/-0.0350
# Current LR = 1.000e-04
# EPOCH 25:
#  Avg. train loss/batch after 10 batches = -0.0404
#  Avg. train loss/batch after 20 batches = -0.0465
#  Avg. train loss/batch after 30 batches = -0.0640
#  Avg. train loss/batch after 40 batches = -0.0596
#  Avg. train loss/batch after 50 batches = -0.0694
#  Avg. train loss/batch after 60 batches = -0.0827
#  Avg. train loss/batch after 70 batches = -0.0886
#  Avg. train loss/batch after 80 batches = -0.0972
# Train/Val flow Loss after epoch: -0.0972/-0.1002
# Current LR = 1.000e-04
# EPOCH 26:
#  Avg. train loss/batch after 10 batches = -0.1051
#  Avg. train loss/batch after 20 batches = -0.1135
#  Avg. train loss/batch after 30 batches = -0.1165
#  Avg. train loss/batch after 40 batches = -0.1314
#  Avg. train loss/batch after 50 batches = -0.1373
#  Avg. train loss/batch after 60 batches = -0.1303
#  Avg. train loss/batch after 70 batches = -0.1444
#  Avg. train loss/batch after 80 batches = -0.1460
# Train/Val flow Loss after epoch: -0.1460/-0.1483
# Current LR = 1.000e-04
# EPOCH 27:
#  Avg. train loss/batch after 10 batches = -0.1606
#  Avg. train loss/batch after 20 batches = -0.1531
#  Avg. train loss/batch after 30 batches = -0.1745
#  Avg. train loss/batch after 40 batches = -0.1854
#  Avg. train loss/batch after 50 batches = -0.1922
#  Avg. train loss/batch after 60 batches = -0.2029
#  Avg. train loss/batch after 70 batches = -0.1860
#  Avg. train loss/batch after 80 batches = -0.2039
# Train/Val flow Loss after epoch: -0.2039/-0.2066
# Current LR = 1.000e-04
# EPOCH 28:
#  Avg. train loss/batch after 10 batches = -0.2222
#  Avg. train loss/batch after 20 batches = -0.2167
#  Avg. train loss/batch after 30 batches = -0.2310
#  Avg. train loss/batch after 40 batches = -0.2267
#  Avg. train loss/batch after 50 batches = -0.2336
#  Avg. train loss/batch after 60 batches = -0.2377
#  Avg. train loss/batch after 70 batches = -0.2454
#  Avg. train loss/batch after 80 batches = -0.2532
# Train/Val flow Loss after epoch: -0.2532/-0.2472
# Current LR = 1.000e-04
# EPOCH 29:
#  Avg. train loss/batch after 10 batches = -0.2585
#  Avg. train loss/batch after 20 batches = -0.2614
#  Avg. train loss/batch after 30 batches = -0.2726
#  Avg. train loss/batch after 40 batches = -0.2835
#  Avg. train loss/batch after 50 batches = -0.2854
#  Avg. train loss/batch after 60 batches = -0.2928
#  Avg. train loss/batch after 70 batches = -0.2954
#  Avg. train loss/batch after 80 batches = -0.2990
# Train/Val flow Loss after epoch: -0.2990/-0.2940
# Current LR = 1.000e-04
# EPOCH 30:
#  Avg. train loss/batch after 10 batches = -0.3067
#  Avg. train loss/batch after 20 batches = -0.3196
#  Avg. train loss/batch after 30 batches = -0.3144
#  Avg. train loss/batch after 40 batches = -0.3252
#  Avg. train loss/batch after 50 batches = -0.3254
#  Avg. train loss/batch after 60 batches = -0.3363
#  Avg. train loss/batch after 70 batches = -0.3312
#  Avg. train loss/batch after 80 batches = -0.3420
# Train/Val flow Loss after epoch: -0.3420/-0.3494
# Current LR = 1.000e-04
# EPOCH 31:
#  Avg. train loss/batch after 10 batches = -0.3472
#  Avg. train loss/batch after 20 batches = -0.3563
#  Avg. train loss/batch after 30 batches = -0.3508
#  Avg. train loss/batch after 40 batches = -0.3694
#  Avg. train loss/batch after 50 batches = -0.3774
#  Avg. train loss/batch after 60 batches = -0.3723
#  Avg. train loss/batch after 70 batches = -0.3773
#  Avg. train loss/batch after 80 batches = -0.3739
# Train/Val flow Loss after epoch: -0.3739/-0.3869
# Current LR = 1.000e-04
# EPOCH 32:
#  Avg. train loss/batch after 10 batches = -0.3918
#  Avg. train loss/batch after 20 batches = -0.3927
#  Avg. train loss/batch after 30 batches = -0.3989
#  Avg. train loss/batch after 40 batches = -0.3894
#  Avg. train loss/batch after 50 batches = -0.3997
#  Avg. train loss/batch after 60 batches = -0.4176
#  Avg. train loss/batch after 70 batches = -0.4169
#  Avg. train loss/batch after 80 batches = -0.4216
# Train/Val flow Loss after epoch: -0.4216/-0.4162
# Current LR = 1.000e-04
# EPOCH 33:
#  Avg. train loss/batch after 10 batches = -0.4281
#  Avg. train loss/batch after 20 batches = -0.4257
#  Avg. train loss/batch after 30 batches = -0.4299
#  Avg. train loss/batch after 40 batches = -0.4373
#  Avg. train loss/batch after 50 batches = -0.4512
#  Avg. train loss/batch after 60 batches = -0.4524
#  Avg. train loss/batch after 70 batches = -0.4416
#  Avg. train loss/batch after 80 batches = -0.4560
# Train/Val flow Loss after epoch: -0.4560/-0.4608
# Current LR = 1.000e-04
# EPOCH 34:
#  Avg. train loss/batch after 10 batches = -0.4629
#  Avg. train loss/batch after 20 batches = -0.4719
#  Avg. train loss/batch after 30 batches = -0.4690
#  Avg. train loss/batch after 40 batches = -0.4690
#  Avg. train loss/batch after 50 batches = -0.4762
#  Avg. train loss/batch after 60 batches = -0.4643
#  Avg. train loss/batch after 70 batches = -0.4810
#  Avg. train loss/batch after 80 batches = -0.4866
# Train/Val flow Loss after epoch: -0.4866/-0.4721
# Current LR = 1.000e-04
# EPOCH 35:
#  Avg. train loss/batch after 10 batches = -0.4890
#  Avg. train loss/batch after 20 batches = -0.5036
#  Avg. train loss/batch after 30 batches = -0.4957
#  Avg. train loss/batch after 40 batches = -0.4852
#  Avg. train loss/batch after 50 batches = -0.4989
#  Avg. train loss/batch after 60 batches = -0.5005
#  Avg. train loss/batch after 70 batches = -0.5196
#  Avg. train loss/batch after 80 batches = -0.5232
# Train/Val flow Loss after epoch: -0.5232/-0.5132
# Current LR = 1.000e-04
# EPOCH 36:
#  Avg. train loss/batch after 10 batches = -0.5198
#  Avg. train loss/batch after 20 batches = -0.5132
#  Avg. train loss/batch after 30 batches = -0.5284
#  Avg. train loss/batch after 40 batches = -0.5189
#  Avg. train loss/batch after 50 batches = -0.5182
#  Avg. train loss/batch after 60 batches = -0.5355
#  Avg. train loss/batch after 70 batches = -0.5320
#  Avg. train loss/batch after 80 batches = -0.5551
# Train/Val flow Loss after epoch: -0.5551/-0.5384
# Current LR = 1.000e-04
# EPOCH 37:
#  Avg. train loss/batch after 10 batches = -0.5496
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:8
#
# Cell In[53], line 12, in train_one_epoch(epoch_index, tb_writer)
#       9 theta = augmented_theta.reshape(-1, 2)
#      10 data = augmented_data.reshape(-1, 1, num_points)
# ---> 12 flow_loss = -flow.log_prob(theta, context=data).mean()
#      14 optimizer.zero_grad()
#      15 flow_loss.backward()
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/nflows/distributions/base.py:40, in Distribution.log_prob(self, inputs, context)
#      36     if inputs.shape[0] != context.shape[0]:
#      37         raise ValueError(
#      38             "Number of input items must be equal to number of context items."
#      39         )
# ---> 40 return self._log_prob(inputs, context)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/nflows/flows/base.py:38, in Flow._log_prob(self, inputs, context)
#      37 def _log_prob(self, inputs, context):
# ---> 38     embedded_context = self._embedding_net(context)
#      39     noise, logabsdet = self._transform(inputs, context=embedded_context)
#      40     log_prob = self._distribution.log_prob(noise, context=embedded_context)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[49], line 23, in EmbeddingNet.forward(self, x)
#      21 batch_size, _, dims = x.shape
#      22 x = x.reshape(batch_size, 1, dims).repeat(1, num_repeats, 1)
# ---> 23 _, rep = self.representation_net(x)
#      24 return self.context_layer(rep.reshape(batch_size, num_dim))
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[28], line 24, in SimilarityEmbedding.forward(self, x)
#      23 def forward(self, x):
# ---> 24     x = self.layers_f(x)
#      25     x = self.contraction_layer(x)
#      26     representation = torch.clone(x) #copy
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[27], line 81, in ConvResidualNet.forward(self, inputs)
#      79 temps = self.initial_layer(inputs)
#      80 for block in self.blocks:
# ---> 81     temps = block(temps)
#      82 outputs = self.final_layer(temps)
#      83 return outputs
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[27], line 33, in ConvResidualBlock.forward(self, inputs)
#      31     temps = self.batch_norm_layers[0](temps)
#      32 temps = self.activation(temps)
# ---> 33 temps = self.conv_layers[0](temps)
#      34 if self.use_batch_norm:
#      35     temps = self.batch_norm_layers[1](temps)
#
# File /work/submit/kyoon/miniforge3/envs/ssm/lib/python3.10/site-packages/torch/nn/modules/module.py:1716, in Module.__getattr__(self, name)
#    1707         self._backward_pre_hooks = OrderedDict()
#    1709 # On the return type:
#    1710 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1711 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1714 # See full discussion on the problems with returning `Union` here
#    1715 # https://github.com/microsoft/pyright/issues/4213
# -> 1716 def __getattr__(self, name: str) -> Any:
#    1717     if '_parameters' in self.__dict__:
#    1718         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
PATH2 = './damped-harmonic-oscillator-with-similarity-embedding-flow-weights.neurips.pth'
torch.save(flow.state_dict(), PATH2)

# %% [markdown]
# # Check on test data

# %%
import pandas as pd
import corner

def cast_as_bilby_result(samples, truth):
    injections = dict.fromkeys({'omega_0', 'beta'})
    injections['omega_0'] = float(truth.numpy()[0])
    injections['beta'] = float(truth.numpy()[1])

    posterior = dict.fromkeys({'omega_0', 'beta'})
    samples_numpy = samples.numpy()
    posterior['omega_0'] = samples_numpy.T[0].flatten()
    posterior['beta'] = samples_numpy.T[1].flatten()
    posterior = pd.DataFrame(posterior)

    return bilby.result.Result(
        label="test_data",
        injection_parameters=injections,
        posterior=posterior,
        search_parameter_keys=list(injections.keys()),
        priors=priors
    )

# %%
def live_plot_samples(samples, truth):
    print(truth)
    clear_output(wait=True)
    sleep(0.5)
    figure = corner.corner(
        samples.numpy(), quantiles=[0.05, 0.5, 0.95],
        show_titles=True,
        labels=["omega_0", "beta",],
        truth=truth,
    )

    corner.overplot_lines(figure, truth, color="C1")
    corner.overplot_points(figure, truth[None], marker="s", color="C1")

# %% [markdown]
# ## Posteriors

# %%
for idx, (_, theta_test, data_test, data_orig) in enumerate(test_data_loader):
    if idx % 1000 != 0: continue 
    with torch.no_grad():
        samples = flow.sample(3000, context=data_test[0][0].reshape((1, 1, 200)))
    live_plot_samples(samples.cpu().reshape(3000, 2), theta_test[0][0].cpu()[..., 0:2])
    plt.show()

# %% [markdown]
# # PP plot

# %%
# %%time
results = []
for idx, (_, theta_test, data_test, data_unshifted) in enumerate(test_data_loader):
    if idx==1000: break
    with torch.no_grad():
        samples = flow.sample(3000, context=data_test[0][0].reshape((1, 1, 200)))
    results.append(
        cast_as_bilby_result(samples.cpu().reshape(3000, 2), theta_test[0][0].cpu()[...,0:2]))

import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    bilby.result.make_pp_plot(results, save=True, filename='sho-pp-plot-n-1000.pdf',
                              keys=['omega_0', 'beta'], title=None)
# Out:
# 09:55 bilby INFO    : Key: KS-test p-value
# 09:55 bilby INFO    : omega_0: 0.053935815463856396
# 09:55 bilby INFO    : beta: 0.04283874941140986
# 09:55 bilby INFO    : Combined p-value: 0.016336168424183565
# CPU times: user 7min 23s, sys: 1.45 s, total: 7min 25s
# Wall time: 33.2 s

# %% [markdown]
# # Comparison with bilby and analytic result

# %%
import bilby
bilby_result = bilby.result.Result.from_json('./bilby_sho.json', outdir=None)

# %%
bilby_result.injection_parameters.pop('shift')
injection_parameters = bilby_result.injection_parameters.copy()

# %%
x_vals = damped_sho_bilby(t_vals, **injection_parameters)
x_vals = x_vals.to(device, dtype=torch.float32)

# %%
with torch.no_grad():
    flow_samples = flow.sample(3000, context=x_vals.reshape((1, 1, 200)))

# %%
flow_result = cast_as_bilby_result(flow_samples.cpu().reshape(3000, 2),
                                   torch.tensor(list(injection_parameters.values())))

# %%
fig = bilby.result.plot_multiple(
    [flow_result, bilby_result],
    labels=['Flow', 'Bilby'],
    truth=injection_parameters,
    quantiles=(0.16, 0.84),
    titles=True,
    save=False
)
